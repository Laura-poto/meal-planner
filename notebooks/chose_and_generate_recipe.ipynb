# %%
# =========================
#   RECETTES → SCORES & COURSES
# =========================
import json, math, re, unicodedata
from pathlib import Path
from collections import defaultdict

# ---------- PARAMÈTRES ----------
MATCH_MIN = 100  # filtre des recettes selon score marché (%)
MATCH_MIN_PANTRY = 0   # % minimum côté placard (ex. 100 pour ne garder que 100%)

#paramètres non choisis par l'utilisateur
PANTRY_RAYONS = {"boucherie", "poissonnerie", "épicerie"}  # rayons à scorer côté placard
CATEGORY_ORDER = [
    "craquage","pâtes végé","végé","poulet","boeuf haché","boeuf",
    "porc","canard","saumon","poisson blanc","crevettes","tarte","soupe",
]
FLOAT_EPS = 1e-9  # tolérance flottants

# ---------- CHARGEMENT DONNÉES ----------
DATA_DIR = Path("../data")
recettes = json.load(open(str(DATA_DIR / "recettes_hellofresh.txt"), encoding="utf-8"))
catalogue = json.load(open(str(DATA_DIR / "ingredients_infos.txt"), encoding="utf-8"))
raw_dispos = set(json.load(open(str(DATA_DIR / "ingredients_disponibles.txt"), encoding="utf-8")))

provisions_path = Path("../data/provisions.txt")
provisions = json.load(open(provisions_path, encoding="utf-8")) if provisions_path.exists() else []

# ---------- NORMALISATION / ALIASES ----------
ALIASES = {
    "Emmental râpé": "Emmental",
    "Dés de butternut": "Butternut",
    "Fricassée de champignons émincés": "Champignon",
    "Gingembre frais": "Gingembre",
    "Oignon jaune": "Oignon",
    "Poivron rouge": "Poivron",
    "Poivrons grillés": "Poivron",
    "Pommes de terre Franceline": "Pommes de terre",
    "Pommes de terre à chair farineuse": "Pommes de terre",
    "Pommes de terre à chair ferme": "Pommes de terre",
    "Purée de gingembre": "Gingembre",
    "Tomates cerises rouges": "Tomates cerises",
    "Tomates cerises rouges et jaunes": "Tomates cerises",
    "Mélange de jeunes pousses": "Salade",
    "Mélange de salades": "Salade",
    "Chou rouge découpé": "Chou rouge",
    "Champignons blonds": "Champignons",
    "Champignons de Paris": "Champignons",
    "Gousse d'ail": "Ail"
}

def normalize(s: str) -> str:
    if not s: return ""
    s = unicodedata.normalize("NFD", s.lower())
    s = "".join(c for c in s if unicodedata.category(c) != "Mn")
    words = s.split()
    singularized = []
    for w in words:
        if len(w) > 3 and re.search(r"[sx]$", w):
            w = re.sub(r"[sx]$", "", w)
        singularized.append(w)
    return " ".join(singularized)

ALIASES_NORM = {normalize(k): v for k, v in ALIASES.items()}
def canon(name: str) -> str:
    return ALIASES_NORM.get(normalize(name), name)

# ---------- INDEX ----------
# catalogue
CATALOGUE_NORM_TO_PRETTY = {normalize(canon(i["name"])): canon(i["name"]) for i in catalogue}
rayons_map = {normalize(canon(i["name"])): i.get("rayon", "").lower() for i in catalogue}
indispensables_map = {normalize(canon(i["name"])): bool(i.get("indispensable")) for i in catalogue}
poids_map = {normalize(canon(i["name"])): i.get("poids") for i in catalogue}

# remplacements (tous rayons)
REPLACEMENTS_NORM = {}
for item in catalogue:
    base = normalize(canon(item["name"]))
    repls = {normalize(canon(r)) for r in item.get("remplacement", [])}
    REPLACEMENTS_NORM[base] = repls | {base}

# ingrédients_disponibles → pretty & norm
dispo_norm_to_pretty = {}
for d in raw_dispos:
    pretty = canon(d)
    dispo_norm_to_pretty.setdefault(normalize(pretty), pretty)
dispos_norm = set(dispo_norm_to_pretty.keys())

# provisions
provisions_index = {normalize(canon(p["name"])): p for p in provisions}

# indispensables marché
catalogue_norm_index = {normalize(canon(i["name"])): i for i in catalogue}
market_indispensables_norm = {
    normalize(canon(i["name"]))
    for i in catalogue
    if i.get("indispensable") and i.get("rayon", "").lower() == "marché"
}

# ---------- HELPERS ----------
def pretty_from_norm(n: str) -> str:
    return CATALOGUE_NORM_TO_PRETTY.get(n, dispo_norm_to_pretty.get(n, n))

def find_available_market(norm_name: str):
    for cand in [norm_name] + [c for c in REPLACEMENTS_NORM.get(norm_name, {norm_name}) if c != norm_name]:
        if cand in dispos_norm:
            return cand
    return None

def find_available_pantry(norm_name: str):
    cand_list = [norm_name] + [c for c in REPLACEMENTS_NORM.get(norm_name, {norm_name}) if c != norm_name]
    for cand in cand_list:
        if cand in provisions_index:
            return cand
    return None

# ---------- SCORING RECETTES ----------
def score_recette(r):
    rec_ing_pretty = {canon(n) for n in r["ingredients"].keys()}
    rec_ing_norm = {normalize(n) for n in rec_ing_pretty}
    inconnus = sorted(n for n in rec_ing_pretty if normalize(n) not in catalogue_norm_index)

    # marché
    besoins_m = market_indispensables_norm & rec_ing_norm
    ok_m, manque_m = [], []
    if besoins_m:
        for n_norm in besoins_m:
            base_pretty = pretty_from_norm(n_norm)
            cand = find_available_market(n_norm)
            if cand is None:
                manque_m.append(base_pretty)
            else:
                if cand != n_norm:
                    ok_m.append(f"{base_pretty} (remplacé par : {pretty_from_norm(cand)})")
                else:
                    ok_m.append(base_pretty)
        score_m = 100 * len(ok_m) / len(besoins_m)
    else:
        score_m = 100.0

    # placard (rayons choisis)
    besoins_p = {n for n in rec_ing_norm if rayons_map.get(n) in PANTRY_RAYONS}
    ok_p, manque_p = [], []
    if besoins_p:
        for n_norm in besoins_p:
            base_pretty = pretty_from_norm(n_norm)
            cand = find_available_pantry(n_norm)
            if cand is None:
                manque_p.append(base_pretty)
            else:
                if cand != n_norm:
                    ok_p.append(f"{base_pretty} (remplacé par : {pretty_from_norm(cand)})")
                else:
                    ok_p.append(base_pretty)
        score_p = 100 * len(ok_p) / len(besoins_p)
    else:
        score_p = 100.0

    return {
        "name": r["name"],
        "link": r["link"],
        "category": r.get("category", "non classé"),
        "score_market": round(score_m, 1),
        "score_pantry": round(score_p, 1),
        "ok_market": sorted(ok_m),
        "manque_market": sorted(manque_m),
        "ok_pantry": sorted(ok_p),
        "manque_pantry": sorted(manque_p),
        "inconnus": inconnus,
    }

# ---------- CALCUL & AFFICHAGE DES SCORES ----------
scored, unknown_global_pretty, seen = [], set(), set()
for r in recettes:
    key = r["name"]
    if key in seen: 
        continue
    seen.add(key)
    s = score_recette(r)
    scored.append(s)
    unknown_global_pretty.update(s["inconnus"])

# filtre par score marché et score_pantry
scored = [
    r for r in scored
    if r["score_market"] >= MATCH_MIN and r["score_pantry"] >= MATCH_MIN_PANTRY
]

# tri: catégorie -> score placard desc -> nom
def sort_key_recette(r):
    cat = r.get("category", "").lower()
    cat_index = CATEGORY_ORDER.index(cat) if cat in CATEGORY_ORDER else len(CATEGORY_ORDER)
    return (cat_index, -r["score_pantry"], r["name"].lower())
scored.sort(key=sort_key_recette)

# affichage
current_cat = None
for r in scored:
    cat = r.get("category", "non classé")
    if cat != current_cat:
        print(f"\n=== {cat.upper()} ===\n")
        current_cat = cat
    print(f"{r['score_market']}% marché & {r['score_pantry']}% placard - {r['name']} ({r['link']})")
    print("   OK marché :", ", ".join(r["ok_market"]) if r["ok_market"] else "Aucun")
    print("   Manque marché :", ", ".join(r["manque_market"]) if r["manque_market"] else "Aucun")
    print("   OK placard :", ", ".join(r["ok_pantry"]) if r["ok_pantry"] else "Aucun")
    print("   Manque placard :", ", ".join(r["manque_pantry"]) if r["manque_pantry"] else "Aucun")
    if r["inconnus"]:
        print("[⚠️] Ingrédients non définis dans ingredients_infos.txt : " + ", ".join(r["inconnus"]))
    print()

# ----- Générer ingredients_a_completer.txt -----
unknown_global_pretty = sorted(n for n in unknown_global_pretty if normalize(n) not in catalogue_norm_index)
TEMPLATE_MONTHS = ["janvier","février","mars","avril","mai","juin","juillet","août","septembre","octobre","novembre","décembre"]
def render_ing_block(name: str) -> str:
    return (
        "  {\n"
        f"    \"name\": \"{name}\",\n"
        f"    \"saison\": {json.dumps(TEMPLATE_MONTHS, ensure_ascii=False)},\n"
        f"    \"rayon\": \"à définir\",\n"
        f"    \"indispensable\": true\n"
        "  }"
    )
out_path = Path("../data/ingredients_a_completer.txt")
with open(out_path, "w", encoding="utf-8") as f:
    blocks = [render_ing_block(n) for n in unknown_global_pretty]
    f.write(",\n".join(blocks))
print(f"→ {len(unknown_global_pretty)} ingrédient(s) à compléter écrit(s) dans {out_path.resolve()}")
# Out:
# === CRAQUAGE ===
#
# 100.0% marché & 100.0% placard - La pâte à galettes de blé noir traditionnelle (https://www.marmiton.org/recettes/recette_la-pate-a-galettes-de-ble-noir-traditionnelle_35351.aspx)
#    OK marché : Champignon
#    Manque marché : Aucun
#    OK placard : Crème liquide
#    Manque placard : Aucun
#
# 100.0% marché & 50.0% placard - Gratin de ravioles du Dauphiné au comté (https://www.750g.com/gratin-de-ravioles-du-dauphine-au-comte-r208023.htm)
#    OK marché : Aucun
#    Manque marché : Aucun
#    OK placard : Crème liquide
#    Manque placard : Escalope de veau
#
# 100.0% marché & 0.0% placard - Croque-monsieur (https://www.marmiton.org/recettes/recette_croque-monsieur_19208.aspx)
#    OK marché : Aucun
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Pain de mie
#
# 100.0% marché & 0.0% placard - Croziflette (https://www.marmiton.org/recettes/recette_croziflette_165464.aspx)
#    OK marché : Oignon
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Crozet au sarrasin
#
#
# === PÂTES VÉGÉ ===
#
# 100.0% marché & 100.0% placard - Butternut grillé, labneh & beurre au curcuma (https://www.hellofresh.fr/recipes/butternut-grille-labneh-and-beurre-au-curcuma-634578e5602ededf96020aa9)
#    OK marché : Courge butternut (remplacé par : Potimarron), Échalote
#    Manque marché : Aucun
#    OK placard : Couscous perlé (remplacé par : Semoule), Tomates semi-séchées
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Conchiglie & fricassée de champignons (https://www.hellofresh.fr/recipes/conchiglie-and-fricassee-de-champignons-63456c5f14419253d70b2bbb)
#    OK marché : Champignon, Oignon rouge, Salade
#    Manque marché : Aucun
#    OK placard : Conchiglie (remplacé par : torsade), Crème liquide
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Linguine et pesto d’épinards maison (https://www.hellofresh.fr/recipes/linguine-et-pesto-depinards-maison-616e8bb725f0ce4a3711b11b)
#    OK marché : Salade, Épinards
#    Manque marché : Aucun
#    OK placard : Linguine (remplacé par : Spaghetti), Tomates semi-séchées
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Mac & Cheese au potiron (https://www.hellofresh.fr/recipes/mac-and-cheese-au-potiron-5f8554e564586a2b8413e2e4)
#    OK marché : Butternut, Oignon, Épinards
#    Manque marché : Aucun
#    OK placard : Coquillette
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Penne & crème de tomates séchées (https://www.hellofresh.fr/recipes/penne-and-creme-de-tomates-sechees-61657b6b2d4427482818069e)
#    OK marché : Carotte, Oignon, Salade
#    Manque marché : Aucun
#    OK placard : Crème liquide, Penne (remplacé par : torsade), Tomates semi-séchées
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Rigatoni, endives poêlées & comté (https://www.hellofresh.fr/recipes/rigatoni-endives-poelees-and-comte-603e710dce4e090209336f6d)
#    OK marché : Endive, Mélange de champignons prédécoupés (remplacé par : Champignon), Oignon
#    Manque marché : Aucun
#    OK placard : Crème liquide, Rigatoni (remplacé par : torsade)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Soupe de nouilles soba aux champignons (https://www.hellofresh.fr/recipes/soupe-de-nouilles-soba-aux-champignons-60238f93e28c112717016a34)
#    OK marché : Mélange de champignons prédécoupés (remplacé par : Champignon)
#    Manque marché : Aucun
#    OK placard : Nouilles soba (remplacé par : Nouilles plates de riz), Sauce soja, Tomates semi-séchées
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Tagliatelle, crème de pecorino & noix (https://www.hellofresh.fr/recipes/tagliatelle-creme-de-pecorino-and-noix-623ad5f618dec2115f016435)
#    OK marché : Salade
#    Manque marché : Aucun
#    OK placard : Tagliatelle, Tomates semi-séchées
#    Manque placard : Aucun
#
# 100.0% marché & 66.7% placard - Rigatoni al pesto & pomodoro (https://www.hellofresh.fr/recipes/rigatoni-al-pesto-and-pomodoro-64073d04683721c9a32b0811)
#    OK marché : Champignon, Oignon, Salade
#    Manque marché : Aucun
#    OK placard : Rigatoni (remplacé par : torsade), Tomates semi-séchées
#    Manque placard : Pesto vert
#
# 100.0% marché & 66.7% placard - Wok de nouilles udon aux légumes & gomasio (https://www.hellofresh.fr/recipes/wok-de-nouilles-udon-aux-legumes-and-gomasio-5f60ae504e8ae57f155d7b15)
#    OK marché : Carotte, Chou rouge, Poireau, Épinards
#    Manque marché : Aucun
#    OK placard : Nouilles udon fraîches (remplacé par : Nouilles plates de riz), Sauce soja
#    Manque placard : Sauce au chili sucrée et épicée
#
# 100.0% marché & 50.0% placard - Gnocchi aux champignons et à la crème (https://www.hellofresh.lu/recipes/gnocchi-aux-champignons-et-a-la-creme-609e988a651ba1441f15761b)
#    OK marché : Champignon, Oignon, Épinards
#    Manque marché : Aucun
#    OK placard : Crème liquide
#    Manque placard : Gnocchi
#
# 100.0% marché & 50.0% placard - Rigatoni au pesto verde, épinards & burrata (https://www.hellofresh.fr/recipes/rigatoni-au-pesto-verde-epinards-and-burrata-64fb2d9671b62ce1283423d2)
#    OK marché : Oignon, Épinards
#    Manque marché : Aucun
#    OK placard : Rigatoni (remplacé par : torsade)
#    Manque placard : Pesto vert
#
# 100.0% marché & 33.3% placard - Gratin éclair de gnocchi, champis & épinards (https://www.hellofresh.fr/recipes/gratin-eclair-de-gnocchi-champis-and-epinards-65e58e07f5a5196d85e983be)
#    OK marché : Champignon, Épinards
#    Manque marché : Aucun
#    OK placard : Crème liquide
#    Manque placard : Gnocchi, Pesto vert
#
# 100.0% marché & 0.0% placard - Orzo façon risotto aux épinards & poireau (https://www.hellofresh.fr/recipes/orzo-facon-risotto-aux-epinards-and-poireau-6243130885c236274169657e)
#    OK marché : Oignon, Poireau, Salade, Épinards
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Orzo
#
#
# === VÉGÉ ===
#
# 100.0% marché & 100.0% placard - Berkoukes sans viande : couscous perlé & céleri (https://www.hellofresh.fr/recipes/berkoukes-sans-viande-couscous-perle-and-cumin-66a8b1d071ae0e887989f7ed)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Chair de tomates, Couscous perlé (remplacé par : Semoule), Pois chiches
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Crumble au potimarron & pecorino (https://www.hellofresh.fr/recipes/crumble-au-potimarron-and-pecorino-63bd57e9e9fa190ed6078290)
#    OK marché : Poireau, Potimarron, Salade, Épinards
#    Manque marché : Aucun
#    OK placard : Chapelure panko
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Crumble poireau, noix de pécan & pecorino (https://www.hellofresh.fr/recipes/crumble-poireau-noix-de-pecan-and-pecorino-618151d6a611b50e063c096f)
#    OK marché : Carotte, Champignon, Oignon, Poireau, Salade, Échalote
#    Manque marché : Aucun
#    OK placard : Chapelure panko
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Curry aux épinards et aux patates douces (https://www.hellofresh.fr/recipes/curry-aux-epinards-et-aux-patates-douces-5e5f567195d95b221a29ff6c)
#    OK marché : Oignon, Patate douce, Épinards
#    Manque marché : Aucun
#    OK placard : Lait de coco, Riz
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Green lasagne poireaux-épinards (https://www.hellofresh.fr/recipes/lasagne-poireaux-and-epinards-64fb2d2532e9107c6db883de)
#    OK marché : Oignon, Poireau, Épinards
#    Manque marché : Aucun
#    OK placard : Crème liquide, Feuilles de lasagne
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Salade de couscous perlé, feta & pistaches (https://www.hellofresh.fr/recipes/salade-de-couscous-perle-feta-and-pistaches-61f0341d7f66ba6620393a22)
#    OK marché : Patate douce
#    Manque marché : Aucun
#    OK placard : Couscous perlé (remplacé par : Semoule), Pois chiches, Tomates semi-séchées
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Salade de couscous perlé, feta rôtie & sésame (https://www.hellofresh.fr/recipes/salade-de-couscous-perle-feta-rotie-and-sesame-61f945ecb4a2b76faf1c6c52)
#    OK marché : Carotte, Radis, Salade
#    Manque marché : Aucun
#    OK placard : Couscous perlé (remplacé par : Semoule), Tomates semi-séchées
#    Manque placard : Aucun
#
# 100.0% marché & 80.0% placard - Curry indien de pois chiches & patate douce (https://www.hellofresh.fr/recipes/curry-indien-de-pois-chiches-and-patate-douce-63456a607a0d2ed8f30e8a02)
#    OK marché : Oignon, Patate douce, Épinards
#    Manque marché : Aucun
#    OK placard : Chair de tomates, Lait de coco, Pois chiches, Riz
#    Manque placard : Chutney de mangue
#
# 100.0% marché & 80.0% placard - Riz au lait de coco & tofu poêlé (https://www.hellofresh.fr/recipes/riz-au-lait-de-coco-and-tofu-poele-60882cce985ddb4c7b0de3a3)
#    OK marché : Carotte, Oignon, Pak choï (remplacé par : chou frisé)
#    Manque marché : Aucun
#    OK placard : Lait de coco, Miel, Riz, Sauce soja
#    Manque placard : Tofu nature BIO
#
# 100.0% marché & 75.0% placard - Dahl de lentilles, patate douce & épinards (https://www.hellofresh.fr/recipes/dahl-de-lentilles-patate-douce-and-epinards-633c277744029bb2460ec763)
#    OK marché : Oignon, Patate douce, Épinards
#    Manque marché : Aucun
#    OK placard : Concentré de tomates, Lait de coco, Lentilles corail
#    Manque placard : Pain naan
#
# 100.0% marché & 66.7% placard - Assiette du levant falafels & labneh (https://www.hellofresh.fr/recipes/assiette-du-levant-falafels-and-carottes-au-miel-6686933a65ae7b0dd911182c)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Miel, Pois chiches
#    Manque placard : Falafels
#
# 100.0% marché & 66.7% placard - Poêlée de lentilles & champignons à la crème (https://www.hellofresh.fr/recipes/poelee-de-lentilles-and-champignons-a-la-creme-615c48bbb38d103e812b44bd)
#    OK marché : Champignon, Poireau, Salade
#    Manque marché : Aucun
#    OK placard : Concentré de tomates, Crème liquide
#    Manque placard : Lentilles vertes
#
# 100.0% marché & 33.3% placard - Bowl de boulgour aux légumes rôtis (https://www.hellofresh.fr/recipes/bowl-de-boulgour-aux-legumes-rotis-6006f549b9aa2a21db05fd46)
#    OK marché : Carotte, Chou-fleur, Oignon rouge, Patate douce, Salade
#    Manque marché : Aucun
#    OK placard : Tomates semi-séchées
#    Manque placard : Boulgour, Raisins secs Sultanines
#
# 100.0% marché & 33.3% placard - Freekeh épicé à l'orientale, carottes & épinards (https://www.hellofresh.fr/recipes/freekeh-epice-a-lorientale-carottes-and-epinards-6294d56bc40fb4b3d808b8e9)
#    OK marché : Carotte, Oignon rouge, Épinards
#    Manque marché : Aucun
#    OK placard : Miel
#    Manque placard : Freekeh, Harissa
#
# 100.0% marché & 33.3% placard - Salade orientale de légumes rôtis (https://www.hellofresh.fr/recipes/salade-orientale-de-legumes-rotis-64d28acab199bd79fa716eb7)
#    OK marché : Carotte, Oignon, Patate douce, Salade
#    Manque marché : Aucun
#    OK placard : Tomates semi-séchées
#    Manque placard : Boulgour, Raisins secs Sultanines
#
# 100.0% marché & 0.0% placard - Risotto d'orzo aux champignons (https://www.hellofresh.fr/recipes/risotto-dorzo-aux-champignons-5ffdbcf27c5227587008318a)
#    OK marché : Mélange de champignons prédécoupés (remplacé par : Champignon), Échalote
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Orzo
#
# 100.0% marché & 0.0% placard - Salade de quinoa, courge rôtie & tahini (https://www.hellofresh.fr/recipes/salade-de-quinoa-courge-rotie-and-tahini-60103846007bed4ed44a028b)
#    OK marché : Courge butternut (remplacé par : Potimarron), Oignon rouge
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Olives Leccino dénoyautées, Quinoa
#
#
# === POULET ===
#
# 100.0% marché & 100.0% placard - Blanc de poulet façon teriyaki (https://www.hellofresh.fr/recipes/aiguillettes-de-poulet-facon-teriyaki-64d3b20ec6d2a3702a70fd91)
#    OK marché : Carotte, Oignon, Poireau
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Riz, Sauce soja
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Blanquette de poulet réconfortante (https://www.hellofresh.fr/recipes/blanquette-de-poulet-reconfortante-63f492cd38856479f90966df)
#    OK marché : Carotte, Poireau, Échalote
#    Manque marché : Aucun
#    OK placard : Crème liquide, Filet de poulet, Riz
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Curry thaï de dinde & patate douce (https://www.hellofresh.fr/recipes/mijote-de-dinde-au-curry-thai-and-patate-douce-650c4655d19550681e3ba6be)
#    OK marché : Carotte, Patate douce
#    Manque marché : Aucun
#    OK placard : Escalope de dinde (remplacé par : Filet de poulet), Lait de coco, Sauce poisson
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Escalope de dinde à la milanaise & spaghetti (https://www.hellofresh.fr/recipes/escalope-de-dinde-a-la-milanaise-and-spaghetti-61ddad8bcef6e7460138d1ef)
#    OK marché : Oignon
#    Manque marché : Aucun
#    OK placard : Chair de tomates, Chapelure panko, Escalope de dinde (remplacé par : Filet de poulet), Spaghetti
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Filet de dinde & chutney pomme-thym maison (https://www.hellofresh.fr/recipes/filet-de-dinde-and-chutney-pomme-thym-maison-672155794251e0dbe4be849d)
#    OK marché : Carotte, Pomme, Échalote
#    Manque marché : Aucun
#    OK placard : Escalope de dinde (remplacé par : Filet de poulet), Miel, Riz
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Filet de poulet à la forestière (https://www.hellofresh.fr/recipes/filet-de-poulet-a-la-forestiere-64073cf29c6d10cd16eab707)
#    OK marché : Carotte, Champignon, Grenailles rouges (remplacé par : Pommes de terre), Salade, Échalote
#    Manque marché : Aucun
#    OK placard : Crème liquide, Filet de poulet
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Mafé revisité au poulet & carotte (https://www.hellofresh.fr/recipes/mafe-revisite-au-poulet-and-carotte-64073d979c6d10cd16eab751)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Beurre de cacahuètes, Concentré de tomates, Filet de poulet, Riz
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Nouilles au poulet épicé & lait de coco (https://www.hellofresh.fr/recipes/nouilles-au-poulet-epice-and-lait-de-coco-6374ba3ba13e2c733a0d37af)
#    OK marché : Carotte, Poireau
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Lait de coco, Nouilles udon fraîches (remplacé par : Nouilles plates de riz), Sauce poisson
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - One pot de penne, poulet & crème de gouda (https://www.hellofresh.fr/recipes/one-pot-de-penne-poulet-and-creme-de-gouda-64fb2d47786cce2df0e015bd)
#    OK marché : Oignon, Poireau
#    Manque marché : Aucun
#    OK placard : Crème liquide, Filet de poulet, Penne (remplacé par : torsade)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Poulet & sauce blanche à l'aneth (https://www.hellofresh.fr/recipes/poulet-and-sauce-blanche-a-laneth-64073faddf6297bb5beef2f0)
#    OK marché : Carotte, Oignon, Salade
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Lentilles corail
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Poulet au miel & semoule à la marocaine (https://www.hellofresh.fr/recipes/poulet-marocain-sucre-sale-au-miel-64fb2dcd786cce2df0e019b0)
#    OK marché : Oignon, Patate douce, Épinards
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Miel, Semoule
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Poulet en papillote à la citronnelle (https://www.hellofresh.fr/recipes/poulet-en-papillote-a-la-citronnelle-6374b6b546dc2e55b1010c03)
#    OK marché : Carotte, Patate douce
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Lait de coco, Sauce poisson
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Poulet parmigiana en sauce tomate (https://www.hellofresh.fr/recipes/poulet-parmigiana-en-sauce-tomate-6357c4e2480dc311ac0bbce5)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Chair de tomates, Chapelure panko, Concentré de tomates, Filet de poulet, Miel, Spaghetti
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Poulet thaï au curry vert & lait de coco (https://www.hellofresh.fr/recipes/poulet-thai-au-curry-vert-and-lait-de-coco-636a245841a58210a7065b81)
#    OK marché : Poireau, Échalote
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Lait de coco, Riz, Sauce poisson
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Poulet à la crème de poireau & muscade (https://www.hellofresh.fr/recipes/poulet-a-la-creme-de-poireau-and-muscade-64073f3b683721c9a32b08df)
#    OK marché : Poireau
#    Manque marché : Aucun
#    OK placard : Crème liquide, Filet de poulet, Riz
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Risotto de poulet & champignons (https://www.hellofresh.fr/recipes/risotto-soyeux-de-poulet-and-champignons-65648f3053b95b70f99920fe)
#    OK marché : Champignon, Échalote
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Riz pour risotto
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Salade aromatique de nouilles au poulet (https://www.hellofresh.fr/recipes/salade-aromatique-de-nouilles-au-poulet-63eb6b707f1abd5e5200fa1a)
#    OK marché : Carotte, Chou blanc (remplacé par : Chou rouge), Chou rouge, Salade
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Nouilles de blé, Sauce soja
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Udon au poulet épicé & bouillon coco (https://www.hellofresh.fr/recipes/udon-au-poulet-epice-and-bouillon-coco-67093aeed1dd98c148b059ce)
#    OK marché : Carotte, Pak choï (remplacé par : chou frisé)
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Lait de coco, Nouilles udon fraîches (remplacé par : Nouilles plates de riz), Sauce poisson
#    Manque placard : Aucun
#
# 100.0% marché & 75.0% placard - Pad see ew : nouilles de riz sautées à la thaï (https://www.hellofresh.fr/recipes/pad-see-ew-nouilles-de-riz-sautees-a-la-thai-63a08f66eae25c78e80389cc)
#    OK marché : Oignon, Pak choï (remplacé par : chou frisé)
#    Manque marché : Aucun
#    OK placard : Hauts de cuisses de poulet (remplacé par : Filet de poulet), Nouilles plates de riz, Sauce soja
#    Manque placard : Sauce Worcestershire
#
# 100.0% marché & 66.7% placard - Saltimbocca de dinde (https://www.hellofresh.fr/recipes/saltimbocca-de-dinde-61000ce1556dd9651d24ec37)
#    OK marché : Champignon
#    Manque marché : Aucun
#    OK placard : Escalope de dinde (remplacé par : Filet de poulet), Spaghetti
#    Manque placard : Pesto vert
#
# 100.0% marché & 66.7% placard - Soupe réconfortante au poulet & couscous perlé (https://www.hellofresh.fr/recipes/soupe-reconfortante-au-poulet-and-couscous-perle-6716568c2afd696502ede06e)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Couscous perlé (remplacé par : Semoule), Filet de poulet
#    Manque placard : Petits pois en conserve
#
# 100.0% marché & 60.0% placard - Poêlée de poulet, pak choï & sauce chili sucrée (https://www.hellofresh.fr/recipes/poelee-de-poulet-pak-choi-and-sauce-chili-sucree-6564b1ab2d94ad532d620cd5)
#    OK marché : Oignon, Pak choï (remplacé par : chou frisé)
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Riz, Sauce soja
#    Manque placard : Mayonnaise, Sauce au chili sucrée et épicée
#
#
# === BOEUF HACHÉ ===
#
# 100.0% marché & 100.0% placard - Lasagnes à la bolognaise (https://www.marmiton.org/recettes/recette_lasagnes-a-la-bolognaise_18215.aspx)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Chair de tomates, Feuilles de lasagne
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Nouilles sautées au bœuf haché (https://www.hellofresh.fr/recipes/nouilles-sautees-au-boeuf-hache-60e45d1831c0d837ec388c5e)
#    OK marché : Carotte, Chou blanc (remplacé par : Chou rouge), Poireau
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Nouilles de blé, Sauce asiatique sucrée (remplacé par : Sauce soja), Sauce poisson
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Penne ragù al forno (https://www.hellofresh.fr/recipes/penne-ragu-al-forno-61b8aa43753fcf40e91b70db)
#    OK marché : Carotte, Salade
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Chair de tomates, Concentré de tomates, Penne (remplacé par : torsade)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Ragù bianco de bœuf & champignons à la crème (https://www.hellofresh.fr/recipes/ragu-bianco-de-boeuf-and-champignons-a-la-creme-61f036d2fd8a055a96724a68)
#    OK marché : Champignon, Poireau, Échalote
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Casarecce (remplacé par : torsade)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Spaghetti & polpette de bœuf (https://www.hellofresh.fr/recipes/spaghetti-sauce-tomate-and-boulettes-de-boeuf-64fb2e1032e9107c6db88991)
#    OK marché : Champignon
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Chair de tomates, Spaghetti
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Spaghetti bolognaise (https://www.marmiton.org/recettes/recette_spaghetti-bolognaise_19840.aspx)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Chair de tomates, Spaghetti
#    Manque placard : Aucun
#
# 100.0% marché & 66.7% placard - Orzo au bœuf haché épicé & fromage italien (https://www.hellofresh.fr/recipes/orzo-au-boeuf-hache-epice-and-fromage-italien-61f9442e24ebc0620b24f37c)
#    OK marché : Chou blanc (remplacé par : Chou rouge), Chou rouge, Oignon, Poireau
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Concentré de tomates
#    Manque placard : Orzo
#
#
# === BOEUF ===
#
# 100.0% marché & 100.0% placard - Bœuf chimichurri & tombée d'épinards (https://www.hellofresh.fr/recipes/boeuf-chimichurri-and-puree-de-patate-douce-64fae7d132e9107c6db86eb3)
#    OK marché : Patate douce, Échalote, Épinards
#    Manque marché : Aucun
#    OK placard : Pavé de bœuf mariné (remplacé par : Bavette de bœuf)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Gyudon : bol de riz au bœuf et oignons (https://www.hellofresh.fr/recipes/gyudon-bol-de-riz-au-boeuf-et-oignons-60db193d03cbf73ae2066aae)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Riz, Rumsteak (remplacé par : Bavette de bœuf), Sauce poisson, Sauce soja
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Nouilles au bœuf sauté à la thaï (https://www.hellofresh.fr/recipes/nouilles-au-boeuf-saute-a-la-thai-62bb06b54bc0527b6403986a)
#    OK marché : Carotte
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Nouilles de blé, Sauce asiatique sucrée (remplacé par : Sauce soja), Sauce soja
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Nouilles épicées au bœuf façon Dan Dan (https://www.hellofresh.fr/recipes/nouilles-epicees-au-boeuf-facon-dan-dan-64073ce5df6297bb5beef1f1)
#    OK marché : Oignon, Pak choï (remplacé par : chou frisé)
#    Manque marché : Aucun
#    OK placard : Beurre de cacahuètes, Bœuf haché, Nouilles de blé, Sauce soja
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Pavé de bœuf sauce au poivre maison (https://www.hellofresh.fr/recipes/pave-de-boeuf-sauce-au-poivre-maison-61d45dbe9e37b94fc55fb1b5)
#    OK marché : Grenailles rouges (remplacé par : Pommes de terre), Poireau
#    Manque marché : Aucun
#    OK placard : Rumsteak (remplacé par : Bavette de bœuf)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Pavé de bœuf sauce Bercy & linguine (https://www.hellofresh.fr/recipes/pave-de-boeuf-sauce-bercy-and-linguine-6149e9feddb1012b034b1886)
#    OK marché : Carotte, Oignon, Échalote
#    Manque marché : Aucun
#    OK placard : Bavette de bœuf, Linguine (remplacé par : Spaghetti)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Pavé de rumsteck & sauce au poivre (https://www.hellofresh.fr/recipes/pave-de-rumsteck-and-sauce-au-poivre-5faacc1330df84123c7d8dcc)
#    OK marché : Carotte, Courge butternut (remplacé par : Potimarron), Salade, Échalote
#    Manque marché : Aucun
#    OK placard : Rumsteak (remplacé par : Bavette de bœuf)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Udon au bœuf haché sauce curry coco (https://www.hellofresh.fr/recipes/udon-au-boeuf-hache-sauce-curry-coco-65085d4253d80a03621137e0)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Bœuf haché, Lait de coco, Nouilles udon fraîches (remplacé par : Nouilles plates de riz)
#    Manque placard : Aucun
#
# 100.0% marché & 75.0% placard - Bowl de bœuf & légumes à la japonaise (https://www.hellofresh.fr/recipes/bowl-de-boeuf-and-legumes-a-la-japonaise-63bd5210500ab730aa09fd30)
#    OK marché : Carotte, Oignon rouge, Pak choï (remplacé par : chou frisé)
#    Manque marché : Aucun
#    OK placard : Riz, Sauce soja, Émincés de bœuf (remplacé par : Bavette de bœuf)
#    Manque placard : Mayonnaise
#
# 100.0% marché & 75.0% placard - Paupiette de veau & linguine façon Romanoff (https://www.hellofresh.fr/recipes/filet-mignon-de-porc-and-linguine-alla-vodka-66f56b36da53878e13e428cf)
#    OK marché : Oignon, Poireau
#    Manque marché : Aucun
#    OK placard : Concentré de tomates, Crème liquide, Linguine (remplacé par : Spaghetti)
#    Manque placard : Paupiette de veau
#
#
# === PORC ===
#
# 100.0% marché & 100.0% placard - Risotto aux poireaux & lardons (https://www.hellofresh.fr/recipes/risotto-aux-poireaux-and-lardons-63184c96252de97ba003d290)
#    OK marché : Poireau
#    Manque marché : Aucun
#    OK placard : Riz pour risotto
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Udon façon carbo-miso (https://www.hellofresh.fr/recipes/udon-facon-carbo-miso-630562d3e4b9ae756b006df2)
#    OK marché : Salade
#    Manque marché : Aucun
#    OK placard : Miso blanc (remplacé par : Sauce soja), Nouilles udon fraîches (remplacé par : Nouilles plates de riz)
#    Manque placard : Aucun
#
# 100.0% marché & 66.7% placard - Nouilles au porc & miso façon mazemen (https://www.hellofresh.fr/recipes/nouilles-au-porc-and-miso-facon-mazemen-63f4a2096880bea2be0fed96)
#    OK marché : Pak choï (remplacé par : chou frisé)
#    Manque marché : Aucun
#    OK placard : Miso blanc (remplacé par : Sauce soja), Nouilles de blé
#    Manque placard : Chair à saucisse
#
# 100.0% marché & 66.7% placard - Porc au caramel vietnamien & riz (https://www.hellofresh.fr/recipes/porc-au-caramel-vietnamien-and-riz-61d45d4baba6a90c9d343c5e)
#    OK marché : Carotte, Poireau
#    Manque marché : Aucun
#    OK placard : Riz, Sauce soja
#    Manque placard : Médaillons de porc
#
# 100.0% marché & 66.7% placard - Porc épicé à la mexicaine & riz au curcuma (https://www.hellofresh.fr/recipes/tacos-bowl-au-porc-hache-652d458d6720825b47fd8ad6)
#    OK marché : Avocat, Oignon
#    Manque marché : Aucun
#    OK placard : Chair de tomates, Riz
#    Manque placard : Chair à saucisse
#
# 100.0% marché & 50.0% placard - Salade de farfalle au lard & sauce ciboulette (https://www.hellofresh.fr/recipes/salade-de-farfalle-au-lard-and-sauce-ciboulette-614094b9e406ec2ce45c2bcf)
#    OK marché : Sucrine (remplacé par : Salade)
#    Manque marché : Aucun
#    OK placard : Farfalle (remplacé par : torsade), Tomates semi-séchées
#    Manque placard : Mayonnaise, Poitrine de porc
#
# 100.0% marché & 50.0% placard - Spaghetti aux poireaux & lardons (https://www.hellofresh.fr/recipes/spaghetti-aux-poireaux-and-lardons-6374af42caa505f06502c8e2)
#    OK marché : Champignon, Poireau
#    Manque marché : Aucun
#    OK placard : Spaghetti
#    Manque placard : Pesto de champignons
#
#
# === CANARD ===
#
# 100.0% marché & 66.7% placard - Salade de nouilles & canette à l'asiatique (https://www.hellofresh.fr/recipes/salade-de-nouilles-and-de-canard-a-lasiatique-64fb2ce9786cce2df0e01394)
#    OK marché : Carotte, Chou blanc (remplacé par : Chou rouge), Chou rouge
#    Manque marché : Aucun
#    OK placard : Nouilles de blé, Sauce soja
#    Manque placard : Filet de canard
#
# 100.0% marché & 50.0% placard - Filet de canard & butternut rôti (https://www.hellofresh.fr/recipes/filet-de-canette-and-butternut-roti-6140b3e17a00146b507be37d)
#    OK marché : Courge butternut (remplacé par : Potimarron), Poireau, Pommes de terre
#    Manque marché : Aucun
#    OK placard : Miel
#    Manque placard : Filet de canard
#
# 100.0% marché & 50.0% placard - Gratin dauphinois & filet de canard (https://www.hellofresh.fr/recipes/gratin-dauphinois-and-filet-de-canard-62286105d33fa1304632cc4a)
#    OK marché : Grenailles rouges (remplacé par : Pommes de terre), Salade, Échalote
#    Manque marché : Aucun
#    OK placard : Crème liquide
#    Manque placard : Filet de canard
#
# 100.0% marché & 50.0% placard - Hachis parmentier au canard de Mamie Odette (https://www.hellofresh.fr/recipes/hachis-parmentier-au-canard-de-mamie-odette-6022a6d5129e9a4fe17c7158)
#    OK marché : Carotte, Grenailles rouges (remplacé par : Pommes de terre), Oignon rouge, Salade
#    Manque marché : Aucun
#    OK placard : Concentré de tomates
#    Manque placard : Confit de canard
#
# 100.0% marché & 0.0% placard - Filet de canette sauce échalote & carottes Vichy (https://www.hellofresh.fr/recipes/filet-de-canette-sauce-echalote-and-carottes-vichy-61a6361b74d13c637614a553)
#    OK marché : Carotte, Grenailles (remplacé par : Pommes de terre), Échalote
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Filet de canard
#
#
# === SAUMON ===
#
# 100.0% marché & 100.0% placard - Blanquette de saumon & riz pilaf (https://www.hellofresh.fr/recipes/blanquette-de-saumon-and-riz-pilaf-61e6d519ad6b361fb814e018)
#    OK marché : Carotte, Poireau, Échalote
#    Manque marché : Aucun
#    OK placard : Crème liquide, Riz, Saumon
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Curry rouge thaï épicé de saumon (https://www.hellofresh.fr/recipes/curry-rouge-thai-epice-de-saumon-62431480fb32f57983767a72)
#    OK marché : Carotte, Poireau
#    Manque marché : Aucun
#    OK placard : Lait de coco, Riz, Sauce poisson, Saumon
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Saumon citronné & purée (https://www.hellofresh.fr/recipes/saumon-citronne-and-puree-62e116862b6b8184f40ad14c)
#    OK marché : Champignon, Grenailles rouges (remplacé par : Pommes de terre)
#    Manque marché : Aucun
#    OK placard : Saumon
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Saumon sauce à l'estragon & grenailles (https://www.hellofresh.fr/recipes/saumon-sauce-a-lestragon-and-grenailles-64fb2dd171b62ce128342552)
#    OK marché : Grenailles (remplacé par : Pommes de terre), Poireau, Échalote
#    Manque marché : Aucun
#    OK placard : Saumon
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Saumon, poireau fondant & crème d'aneth (https://www.hellofresh.fr/recipes/saumon-poireaux-fondants-and-pommes-de-terre-roties-65648f285234ba85b73be53a)
#    OK marché : Poireau, Pommes de terre
#    Manque marché : Aucun
#    OK placard : Crème liquide, Saumon
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Tagliatelles au saumon frais (https://www.marmiton.org/recettes/recette_tagliatelles-au-saumon-frais_11354.aspx)
#    OK marché : Aucun
#    Manque marché : Aucun
#    OK placard : Saumon, Tagliatelle
#    Manque placard : Aucun
#
# 100.0% marché & 50.0% placard - Salade de lentilles, saumon fumé et roquette (https://www.hellofresh.fr/recipes/salade-de-lentilles-saumon-fume-et-roquette-618aa8f0b6085c052f17c0e2)
#    OK marché : Carotte, Salade
#    Manque marché : Aucun
#    OK placard : Tomates semi-séchées
#    Manque placard : Lentilles vertes
#
#
# === POISSON BLANC ===
#
# 100.0% marché & 100.0% placard - Curry de lieu & lait de coco façon Moqueca (https://www.hellofresh.fr/recipes/curry-de-lieu-and-lait-de-coco-facon-moqueca-63c6f9f210a842ff100c0cf5)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Chair de tomates, Filet de lieu noir (remplacé par : poisson blanc), Lait de coco, Riz
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Filet d'églefin et sauce ciboulette (https://www.hellofresh.fr/recipes/filet-deglefin-et-sauce-ciboulette-5e4cf7f5eb292a04614e5efd)
#    OK marché : Carottes en botte (remplacé par : Carotte), Pommes de terre
#    Manque marché : Aucun
#    OK placard : Filet d'églefin (remplacé par : poisson blanc)
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Lieu noir tikka masala & poireau (https://www.hellofresh.fr/recipes/lieu-noir-tikka-masala-and-poireau-621506dd7b73f835462a040b)
#    OK marché : Oignon, Poireau
#    Manque marché : Aucun
#    OK placard : Chair de tomates, Filet de cabillaud sans peau (remplacé par : poisson blanc), Lait de coco, Riz
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Lieu à la meunière & tombée d'épinards (https://www.hellofresh.fr/recipes/lieu-a-la-meuniere-and-tombee-depinards-5f0f1865b68c534acb77bd3a)
#    OK marché : Carotte, Oignon, Épinards
#    Manque marché : Aucun
#    OK placard : Filet de lieu noir (remplacé par : poisson blanc), Lentilles corail
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Linguine à la crème d'aneth & poisson au curry (https://www.hellofresh.fr/recipes/linguine-a-la-creme-daneth-and-poisson-au-curry-658069cebd1df37bfc868696)
#    OK marché : Oignon, Poireau
#    Manque marché : Aucun
#    OK placard : Crème liquide, Filet de lieu noir (remplacé par : poisson blanc), Linguine (remplacé par : Spaghetti)
#    Manque placard : Aucun
#
# 100.0% marché & 50.0% placard - Filet d'églefin poêlé et lentilles cuisinées (https://www.hellofresh.fr/recipes/filet-deglefin-poele-et-lentilles-cuisinees-5ece91df30017a717f796926)
#    OK marché : Carotte, Oignon, Poireau
#    Manque marché : Aucun
#    OK placard : Filet d'églefin sans peau (remplacé par : poisson blanc)
#    Manque placard : Lentilles vertes
#
#
# === CREVETTES ===
#
# 100.0% marché & 80.0% placard - Laksa aux crevettes & lait de coco (https://www.hellofresh.fr/recipes/laksa-aux-crevettes-and-lait-de-coco-632060a7b788869acb0c022a)
#    OK marché : Carotte, Chou rouge
#    Manque marché : Aucun
#    OK placard : Beurre de cacahuètes, Lait de coco, Nouilles de blé, Sauce soja
#    Manque placard : Crevettes
#
# 100.0% marché & 75.0% placard - Curry de crevettes au vadouvan (https://www.hellofresh.fr/recipes/curry-de-crevettes-au-vadouvan-5fd8ce994083e0249b5ad5c9)
#    OK marché : Carotte, Poireau
#    Manque marché : Aucun
#    OK placard : Lait de coco, Riz, Sauce asiatique sucrée (remplacé par : Sauce soja)
#    Manque placard : Crevettes
#
# 100.0% marché & 75.0% placard - Lentilles corail & crevettes au curry (https://www.hellofresh.fr/recipes/lentilles-corail-and-crevettes-au-curry-64074039683721c9a32b092c)
#    OK marché : Oignon, Épinards
#    Manque marché : Aucun
#    OK placard : Concentré de tomates, Lait de coco, Lentilles corail
#    Manque placard : Crevettes
#
# 100.0% marché & 66.7% placard - Riz sauté chinois aux crevettes & champignons (https://www.hellofresh.fr/recipes/riz-saute-chinois-aux-crevettes-and-champignons-638f644d846dc06e63080227)
#    OK marché : Champignon
#    Manque marché : Aucun
#    OK placard : Riz, Sauce soja
#    Manque placard : Crevettes
#
# 100.0% marché & 0.0% placard - Salade d'orzo & crevettes au curry (https://www.hellofresh.fr/recipes/salade-dorzo-and-crevettes-au-curry-6374ad7c021d8c79400b4389)
#    OK marché : Carotte, Chou blanc (remplacé par : Chou rouge), Chou rouge, Radis, Échalote
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Crevettes, Orzo
#
#
# === TARTE ===
#
# 100.0% marché & 100.0% placard - Flammekueche oignons & lardons (https://www.hellofresh.fr/recipes/flammekueche-oignons-and-lardons-624c65f89267e96ddb4341e7)
#    OK marché : Oignon, Pomme, Salade
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Tarte aux poireaux & lardons à l'ancienne (https://www.hellofresh.fr/recipes/tarte-aux-poireaux-and-lardons-a-lancienne-648b67a625862a444bdb62f1)
#    OK marché : Poireau, Salade, Échalote
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Tarte fine camembert & pommes à l'alsacienne (https://www.hellofresh.fr/recipes/tarte-fine-camembert-and-pommes-a-lalsacienne-659bc6fa6b4bf2cf1c67fa64)
#    OK marché : Oignon, Pomme, Salade
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Aucun
#
# 100.0% marché & 0.0% placard - Pizza bianca aux champignons (https://www.hellofresh.fr/recipes/pizza-bianca-aux-champignons-5ebd0185470e7a2f041a9036)
#    OK marché : Champignon, Oignon rouge, Salade
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Pain naan
#
#
# === SOUPE ===
#
# 100.0% marché & 100.0% placard - Chorba aadess : soupe de lentilles égyptienne (https://www.hellofresh.fr/recipes/chorba-aadess-soupe-de-lentilles-egyptienne-637ced2e62a4f00d92047e9c)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Concentré de tomates, Lentilles corail
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Locro de papa : soupe Péruvienne avec de l'avocat (https://www.hellofresh.fr/recipes/locro-de-papa-soupe-peruvienne-avec-de-lavocat-642fdc74f64a988df102a07a)
#    OK marché : Avocat, Carotte, Oignon, Patate douce, Pommes de terre
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Velouté de butternut, crème de coco & curcuma (https://www.hellofresh.fr/recipes/veloute-de-butternut-creme-de-coco-and-curcuma-5faacc8c3455223f4a7ca99d)
#    OK marché : Carotte, Oignon, Potimarron
#    Manque marché : Aucun
#    OK placard : Lait de coco
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Velouté de chou-fleur & parmesan AOP (https://www.hellofresh.fr/recipes/veloute-de-chou-fleur-and-parmesan-aop-638f67612f93e70745067e41)
#    OK marché : Chou-fleur, Oignon, Pommes de terre
#    Manque marché : Aucun
#    OK placard : Aucun
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Velouté de panais, coco & noisettes (https://www.hellofresh.fr/recipes/veloute-de-panais-coco-and-noisettes-615c48ec79610c1e4739481d)
#    OK marché : Carotte, Grenailles rouges (remplacé par : Pommes de terre), Oignon, Panais
#    Manque marché : Aucun
#    OK placard : Lait de coco
#    Manque placard : Aucun
#
# 100.0% marché & 100.0% placard - Waterzooi à la Gantoise (https://www.hellofresh.fr/recipes/waterzooi-a-la-gantoise-5d19d700fca63a001a56020b)
#    OK marché : Carotte, Oignon, Poireau, Pommes de terre
#    Manque marché : Aucun
#    OK placard : Crème liquide, Filet de poulet
#    Manque placard : Aucun
#
# 100.0% marché & 66.7% placard - Velouté lentilles corail, coco & carotte (https://www.hellofresh.fr/recipes/veloute-de-lentilles-corail-coco-and-carotte-668be3b765ae7b0dd9112ec9)
#    OK marché : Carotte, Oignon
#    Manque marché : Aucun
#    OK placard : Lait de coco, Lentilles corail
#    Manque placard : Tortillas
#
#
# === SALADE ===
#
# 100.0% marché & 50.0% placard - Salade de poulet, sucrine & cranberries (https://www.hellofresh.fr/recipes/salade-de-poulet-sucrine-and-cranberries-638f69054552b52b3f0b9e9d)
#    OK marché : Carotte, Sucrine (remplacé par : Salade)
#    Manque marché : Aucun
#    OK placard : Filet de poulet, Miel
#    Manque placard : Cranberries séchées, Mayonnaise
#
# → 0 ingrédient(s) à compléter écrit(s) dans C:\Users\UTILISATEUR\OneDrive\Documents\Orga REPAS\notebooks\ingredients_a_completer.txt

# %%
# =========================
#   PARTIE 2 — COURSES & PLACARD
# =========================

def scale_and_round(value, unit, factor):
    scaled = value * factor
    if unit and unit.lower().startswith("g"):
        return int(math.ceil(scaled / 10.0) * 10), unit
    return int(math.ceil(scaled)), unit

def courses(selection_names, personnes):
    """Construit la liste de courses brute (avant déduction du placard), en marquant la dispo marché."""
    factor = personnes / 2
    result = defaultdict(dict)  # rayon -> {ing_norm -> bucket}

    selected, seen = set(selection_names), set()
    for r in recettes:
        if r["name"] not in selected or r["name"] in seen:
            continue
        seen.add(r["name"])

        for ing_raw, data in r["ingredients"].items():
            pretty = canon(ing_raw)
            n = normalize(pretty)
            rayon = rayons_map.get(n, "inconnu")
            if rayon == "placard":
                continue

            # quantités
            if isinstance(data, dict):
                qty = data.get("qty")
                unit = data.get("unit", "")
                override_indisp = data.get("indispensable", None)
            else:
                qty, unit, override_indisp = None, str(data), None

            indisp_flag = override_indisp if override_indisp is not None else indispensables_map.get(n, False)

            val = None
            if isinstance(qty, (int, float)):
                val, unit = scale_and_round(qty, unit, factor)

            # conversions marché (pièces -> kg / g -> kg)
            if (
                rayon == "marché"
                and isinstance(val, (int, float))
                and unit and unit.strip().lower() in ["pièce","pièces","pièce(s)","piece","pieces","piece(s)"]
                and poids_map.get(n)
            ):
                val = round(val * poids_map[n], 2)
                unit = "kg"
            elif rayon == "marché" and unit and unit.lower().startswith("g") and isinstance(val, (int, float)):
                val = round(val / 1000, 2)
                unit = "kg"

            # dispo marché ?
            is_market = (rayon == "marché")
            market_available = (find_available_market(n) is not None) if is_market else None

            bucket = result[rayon].get(n)
            if not bucket:
                bucket = {
                    "label": pretty, "val": 0, "unit": unit, "indispensable": indisp_flag,
                    "recipes": set(), "norm": n, "market_available": market_available
                }
                result[rayon][n] = bucket

            # cumuls
            bucket["indispensable"] = bucket["indispensable"] or indisp_flag
            if val is None:
                bucket["val"] = None
            elif bucket["val"] is not None:
                bucket["val"] += val
            else:
                bucket["val"] = val
            if not bucket["unit"] and unit:
                bucket["unit"] = unit
            if is_market:
                prev = bucket.get("market_available")
                bucket["market_available"] = bool(prev) or bool(market_available)
            bucket["recipes"].add(r["name"])

    # structure d'affichage
    printable = {}
    for rayon, by_norm in result.items():
        printable[rayon] = {}
        for ing_norm, data in by_norm.items():
            data["recipes"] = sorted(data["recipes"])
            printable[rayon][data["label"]] = {
                "val": data["val"],
                "unit": data["unit"],
                "indispensable": data["indispensable"],
                "recipes": data["recipes"],
                "norm": ing_norm,
                "market_available": data.get("market_available"),
            }
    return printable

# -------- Exemple d’utilisation --------
#paramètres choisis par l'utilisateur
selection = [
   "Bowl de boulgour aux légumes rôtis",
   "Blanquette de poulet réconfortante",
   "Nouilles sautées au bœuf haché",
   "Velouté de chou-fleur & parmesan AOP"
]
personnes = 4
liste_courses = courses(selection, personnes)

# ----- AJUSTEMENT SELON LE PLACARD (avec remplacements) -----
consommation_totale = defaultdict(float)  # quantités réellement prélevées du placard (clé = norm placard/base/remplaçant)
pantry_used = {}  # pour affichage "PLACARD UTILISÉ"

for rayon, items in liste_courses.items():
    for label, data in list(items.items()):
        base_norm = data["norm"]
        val = data["val"]
        if val is None:
            continue

        # recherche robuste dans le placard: base -> (label) -> remplacements
        prov = provisions_index.get(base_norm)
        used_key = base_norm
        if not prov:
            label_norm = normalize(canon(label))
            if label_norm in provisions_index:
                prov = provisions_index[label_norm]
                used_key = label_norm
        if not prov:
            for repl in REPLACEMENTS_NORM.get(base_norm, []):
                if repl in provisions_index:
                    prov = provisions_index[repl]
                    used_key = repl
                    break

        if prov:
            dispo = float(prov.get("quantity", 0))
            used = min(float(val), dispo)
            reste = max(0.0, float(val) - dispo)

            # Ce qu'il reste à acheter
            if reste <= FLOAT_EPS:
                del items[label]
            else:
                data["val"] = round(reste, 2)

            if used > FLOAT_EPS:
                consommation_totale[used_key] += used
                entry = pantry_used.get(used_key)
                if not entry:
                    pantry_label = pretty_from_norm(used_key)
                    entry = {
                        "label": pantry_label, "val": 0.0, "unit": data["unit"],
                        "indispensable": indispensables_map.get(used_key, False),
                        "recipes": set(),
                    }
                    pantry_used[used_key] = entry
                entry["val"] += used
                entry["recipes"].update(data.get("recipes", []))

#arrondir les affichages pour ne pas avoir trop de décimales
def _fmt_amount(val, unit):
    if val is None:
      return ""
    u = (unit or "").lower()

    # règles simples :
    # - kg / l : 2 décimales max
    # - g : entier
    # - pièces : entier
    if u in ("kg", "l"):
        s = f"{float(val):.2f}".rstrip("0").rstrip(".")
    elif u.startswith("g"):
        s = str(int(round(float(val))))
    elif u.startswith(("pièce", "piece")):
        s = str(int(round(float(val))))
    else:
        # défaut : 2 décimales max
        s = f"{float(val):.2f}".rstrip("0").rstrip(".")
    return f"{s} {unit}".strip()


# --- AFFICHAGE COURSES ---
def _print_block(title, dct):
    if not dct:
        return
    print(f"--- {title} ---")
    sorted_ings = sorted(dct.items(), key=lambda x: (not x[1]["indispensable"], x[0].lower()))
    for ing, data in sorted_ings:
        prefix = "[*] " if data["indispensable"] else "[ ] "
        nb_rec = len(data["recipes"])
        titles = " / ".join(data["recipes"])
        if data["val"] is not None:
            print(f"{prefix}{ing}: {_fmt_amount(data['val'], data['unit'])}  dans : {nb_rec} recette(s) ({titles})")
        else:
            shown = data["unit"] if data["unit"] else ""
            print(f"{prefix}{ing}: {shown}  dans : {nb_rec} recette(s) ({titles})")
    print()  # <-- ajoute une ligne blanche entre les blocs


# 1) MARCHÉ vs MARCHÉ NON DISPO
if "marché" in liste_courses:
    ings = liste_courses["marché"]
    marche_dispo, marche_non = {}, {}
    for label, data in ings.items():
        if data.get("market_available"):
            marche_dispo[label] = data
        else:
            marche_non[label] = data
    _print_block("MARCHÉ", marche_dispo)
    _print_block("MARCHÉ NON DISPO", marche_non)

# 2) Autres rayons dans l’ordre conseillé
ordre_rayons = ["boucherie","poissonnerie","fromagerie","herbes","frais","épicerie"]
affiches = {"marché"}
for key in ordre_rayons:
    if key in liste_courses:
        _print_block(key.upper(), liste_courses[key])
        affiches.add(key)

# 3) Rayons restants (ordre alpha)
for rayon, ings in sorted(liste_courses.items()):
    if rayon in affiches:
        continue
    _print_block(rayon.upper(), ings)

# 4) Récap : PLACARD UTILISÉ
if pantry_used:
    pantry_print = {}
    for k, data in pantry_used.items():
        pantry_print[data["label"]] = {
            "val": round(data["val"], 2) if isinstance(data["val"], (int, float)) else data["val"],
            "unit": data["unit"],
            "indispensable": data["indispensable"],
            "recipes": sorted(data["recipes"]),
        }
    _print_block("PLACARD UTILISÉ", pantry_print)
else:
    print("--- PLACARD UTILISÉ ---\n(néant)\n")
# Out:
# --- MARCHÉ ---
# [*] Carotte: 0.78 kg  dans : 3 recette(s) (Blanquette de poulet réconfortante / Bowl de boulgour aux légumes rôtis / Nouilles sautées au bœuf haché)
# [*] Chou blanc: 0.2 kg  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [*] Chou-fleur: 1.6 kg  dans : 2 recette(s) (Bowl de boulgour aux légumes rôtis / Velouté de chou-fleur & parmesan AOP)
# [*] Oignon: 0.2 kg  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
# [*] Oignon rouge: 0.2 kg  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
# [*] Patate douce: 0.3 kg  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
# [*] Poireau: 0.8 kg  dans : 2 recette(s) (Blanquette de poulet réconfortante / Nouilles sautées au bœuf haché)
# [*] Pommes de terre: 0.2 kg  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
# [*] Salade: 0.12 kg  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
# [*] Échalote: 0.16 kg  dans : 1 recette(s) (Blanquette de poulet réconfortante)
# [ ] Ail: 0.06 kg  dans : 3 recette(s) (Blanquette de poulet réconfortante / Nouilles sautées au bœuf haché / Velouté de chou-fleur & parmesan AOP)
#
# --- MARCHÉ NON DISPO ---
# [ ] Citron vert: 0.24 kg  dans : 2 recette(s) (Blanquette de poulet réconfortante / Nouilles sautées au bœuf haché)
# [ ] Coriandre: 0.01 kg  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [ ] Gingembre: 20 cm  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [ ] Menthe: 0.01 kg  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
# [ ] Persil: 2 sachet(s)  dans : 1 recette(s) (Blanquette de poulet réconfortante)
#
# --- FROMAGERIE ---
# [*] Crème épaisse: 100 g  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
# [*] Parmesan: 200 g  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
#
# --- FRAIS ---
# [*] Feta AOP: 100 g  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
#
# --- ÉPICERIE ---
# [*] Boulgour: 170 g  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
# [*] Crème liquide: 200 ml  dans : 1 recette(s) (Blanquette de poulet réconfortante)
# [*] Nouilles de blé: 25 g  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [*] Raisins secs Sultanines: 60 g  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
#
# --- BOULANGERIE ---
# [*] Petit pain: 4 pièce(s)  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
#
# --- FRUITS SECS ---
# [*] Graines de courge: 20 g  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
# [*] Noix de cajou concassées: 40 g  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [ ] Amandes: 80 g  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
#
# --- ÉPICES ---
# [*] Ciboulette: 2 sachet(s)  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
# [*] Cumin en poudre: 1 sachet(s)  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
# [*] Feuille de laurier: 2 pièce(s)  dans : 1 recette(s) (Blanquette de poulet réconfortante)
# [*] Noix de muscade: 20 pincée(s)  dans : 1 recette(s) (Velouté de chou-fleur & parmesan AOP)
# [*] Thym: 10 g  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)
#
# --- PLACARD UTILISÉ ---
# [*] Bœuf haché: 400 g  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [*] Filet de poulet: 400 g  dans : 1 recette(s) (Blanquette de poulet réconfortante)
# [*] Nouilles de blé: 375 g  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [*] Riz: 300 g  dans : 1 recette(s) (Blanquette de poulet réconfortante)
# [*] Sauce poisson: 20 ml  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [*] Sauce soja: 4 sachet(s)  dans : 1 recette(s) (Nouilles sautées au bœuf haché)
# [*] Tomates semi-séchées: 120 g  dans : 1 recette(s) (Bowl de boulgour aux légumes rôtis)

# %%
# ----- DÉCRÉMENTER LES PROVISIONS & GÉNÉRER courses_placard.txt -----
for ing_norm, used in consommation_totale.items():
    prov = provisions_index.get(ing_norm)
    if prov:
        prov["quantity"] = max(0, float(prov.get("quantity", 0)) - float(used))

courses_placard = []
for prov in provisions_index.values():
    qte = float(prov.get("quantity", 0))
    qte_min = float(prov.get("quantity_min", 0))
    if qte < qte_min:
        courses_placard.append({"name": prov["name"], "quantity": round(qte_min - qte, 2)})

with open(provisions_path, "w", encoding="utf-8") as f:
    json.dump(list(provisions_index.values()), f, ensure_ascii=False, indent=2)

courses_placard_path = Path("../data/courses_placard.txt")
with open(courses_placard_path, "w", encoding="utf-8") as f:
    json.dump(courses_placard, f, ensure_ascii=False, indent=2)

print(f"→ Placard mis à jour : {provisions_path.resolve()}")
print(f"→ Réappro placard : {courses_placard_path.resolve()}")
# Out:
# → Placard mis à jour : C:\Users\UTILISATEUR\OneDrive\Documents\Orga REPAS\data\provisions.txt
# → Réappro placard : C:\Users\UTILISATEUR\OneDrive\Documents\Orga REPAS\data\courses_placard.txt
